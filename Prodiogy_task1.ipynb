# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import plotly.graph_objects as go

# %%
x=pd.read_csv('age_gender.csv')
x
# Out:
#        age  ethnicity  gender                        img_name  \
# 0        1          2       0  20161219203650636.jpg.chip.jpg
# 1        1          2       0  20161219222752047.jpg.chip.jpg
# 2        1          2       0  20161219222832191.jpg.chip.jpg
# 3        1          2       0  20161220144911423.jpg.chip.jpg
# 4        1          2       0  20161220144914327.jpg.chip.jpg
# ...    ...        ...     ...                             ...
# 23700   99          0       1  20170120221920654.jpg.chip.jpg
# 23701   99          1       1  20170120134639935.jpg.chip.jpg
# 23702   99          2       1  20170110182418864.jpg.chip.jpg
# 23703   99          2       1  20170117195405372.jpg.chip.jpg
# 23704   99          0       1  20170110182052119.jpg.chip.jpg
#
#                                                   pixels
# 0      129 128 128 126 127 130 133 135 139 142 145 14...
# 1      164 74 111 168 169 171 175 182 184 188 193 199...
# ...

# %%
x.head()
# Out:
#    age  ethnicity  gender                        img_name  \
# 0    1          2       0  20161219203650636.jpg.chip.jpg
# 1    1          2       0  20161219222752047.jpg.chip.jpg
# 2    1          2       0  20161219222832191.jpg.chip.jpg
# 3    1          2       0  20161220144911423.jpg.chip.jpg
# 4    1          2       0  20161220144914327.jpg.chip.jpg
#
#                                               pixels
# 0  129 128 128 126 127 130 133 135 139 142 145 14...
# 1  164 74 111 168 169 171 175 182 184 188 193 199...
# 2  67 70 71 70 69 67 70 79 90 103 116 132 145 155...
# 3  193 197 198 200 199 200 202 203 204 205 208 21...
# 4  202 205 209 210 209 209 210 211 212 214 218 21...

# %%
x.tail()
# Out:
#        age  ethnicity  gender                        img_name  \
# 23700   99          0       1  20170120221920654.jpg.chip.jpg
# 23701   99          1       1  20170120134639935.jpg.chip.jpg
# 23702   99          2       1  20170110182418864.jpg.chip.jpg
# 23703   99          2       1  20170117195405372.jpg.chip.jpg
# 23704   99          0       1  20170110182052119.jpg.chip.jpg
#
#                                                   pixels
# 23700  127 100 94 81 77 77 74 99 102 98 128 145 160 1...
# 23701  23 28 32 35 42 47 68 85 98 103 113 117 130 129...
# 23702  59 50 37 40 34 19 30 101 156 170 177 184 187 1...
# 23703  45 108 120 156 206 197 140 180 191 199 204 207...
# 23704  156 161 160 165 170 173 166 177 183 191 187 18...

# %%
x.shape
# Out:
# (23705, 5)

# %%
print("Total rows: {}".format(len(x)))
print("Total columns: {}".format(len(x.columns)))
# Out:
# Total rows: 20085
# Total columns: 5

# %%
x['age'].value_counts()
# Out:
# 26     2197
# 1      1123
# 28      918
# 35      880
# 24      859
#        ...
# 115       3
# 101       2
# 91        2
# 111       1
# 103       1
# Name: age, Length: 104, dtype: int64

# %%
x['ethnicity'].value_counts()
# Out:
# 0    10078
# 1     4526
# 3     3975
# 2     3434
# 4     1692
# Name: ethnicity, dtype: int64

# %%
x['gender'].value_counts().rename(index={0:'Male',1:'Female'})
# Out:
# Male      12391
# Female    11314
# Name: gender, dtype: int64

# %%
x['pixels']=pd.to_numeric(x['pixels'],errors='coerce')
x['pixels'].fillna(0,inplace=True)
x['pixels']=x['pixels']/255
age_dist=x['age'].value_counts()
ethnicity_dist = x['ethnicity'].value_counts()
gender_dist=x['gender'].value_counts().rename(index={0:'Male',1:'Female'})
def demo_bar(x, y, name):
    fig = go.Figure([go.Bar(x=x, y=y)])
    fig.update_layout(title_text=name)
    fig.show()
def demo_hist(data,name):
  fig=go.Figure([go.Histogram(x=data)])
  fig.update_layout(title_text=name)
  fig.show()

# %%
demo(age_dist.index, age_dist.values, 'Age Distribution')
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
demo(x=ethnicity_dist.index,y=ethnicity_dist.values,name="Ethnicity Distribution")
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
demo(x=gender_dist.index,y=gender_dist.values,name="Gender Distributions")
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
demo_hist(x['age'],'Pixel Value Histogram')
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
x=pd.read_csv('age_gender.csv')
x.head()
ages=x['age']
plt.hist(ages,bins=50,color='blue',edgecolor='black')
plt.title('Distributions of ages in a population')
plt.xlabel("Age")
plt.ylabel("Frequency")
plt.show()
